# %% [markdown]
# <a href="https://colab.research.google.com/github/gokulmpg/Generative_Z2O/blob/main/Tokenizer_nltk_spacy_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tokenizer
# Segmenting text into smaller units known as tokens
#
# ## Types of tokenizer

# %%
import nltk
nltk.download("punkt")
nltk.download('punkt_tab')
import spacy
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.util import ngrams
from transformers import BertTokenizer
from transformers import XLNetTokenizer

def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ### Word-based tokenizer
#
# #### nltk

# %%
text = "This is a sample sentence for word tokenization."
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', 'for', 'word', 'tokenization', '.']

# %%
# This showcases word_tokenize from nltk library

text = "I couldn't help the dog. Can't you do it? Don't be afraid if you are."
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['I', 'could', "n't", 'help', 'the', 'dog', '.', 'Ca', "n't", 'you', 'do', 'it', '?', 'Do', "n't", 'be', 'afraid', 'if', 'you', 'are', '.']

# %% [markdown]
# #### Spacy

# %%
# This showcases the use of the 'spaCy' tokenizer with torchtext's get_tokenizer function

text = "I couldn't help the dog. Can't you do it? Don't be afraid if you are."
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# Making a list of the tokens and priting the list
token_list = [token.text for token in doc]
print("Tokens:", token_list)

# Showing token details
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Tokens: ['I', 'could', "n't", 'help', 'the', 'dog', '.', 'Ca', "n't", 'you', 'do', 'it', '?', 'Do', "n't", 'be', 'afraid', 'if', 'you', 'are', '.']
# I PRON nsubj
# could AUX aux
# n't PART neg
# help VERB ROOT
# the DET det
# dog NOUN dobj
# . PUNCT punct
# Ca AUX aux
# n't PART neg
# you PRON nsubj
# do VERB ROOT
# it PRON dobj
# ? PUNCT punct
# Do AUX aux
# n't PART neg
# be AUX ROOT
# afraid ADJ acomp
# if SCONJ mark
# you PRON nsubj
# are AUX advcl
# . PUNCT punct

# %%
text = "Unicorns are real. I saw a unicorn yesterday."
token = word_tokenize(text)
print(token)
# Out:
# ['Unicorns', 'are', 'real', '.', 'I', 'saw', 'a', 'unicorn', 'yesterday', '.']

# %% [markdown]
# ## Character-based tokenizer

# %%
def char_tokenize(text):
    return [char for char in text]

text = "Hello, World!"
tokens = char_tokenize(text)
print(tokens)
# Out:
# ['H', 'e', 'l', 'l', 'o', ',', ' ', 'W', 'o', 'r', 'l', 'd', '!']

# %% [markdown]
# ## Subword Baseed
#
# ### WordPiece

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
tokenizer.tokenize("IBM taught me tokenization.")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ['ibm', 'taught', 'me', 'token', '##ization', '.']

# %% [markdown]
# ### Unigram and SentencePiece

# %%
tokenizer = XLNetTokenizer.from_pretrained("xlnet-base-cased")
tokenizer.tokenize("IBM taught me tokenization.")
# Out:
# spiece.model:   0%|          | 0.00/798k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.38M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/760 [00:00<?, ?B/s]
# ['▁IBM', '▁taught', '▁me', '▁token', 'ization', '.']
